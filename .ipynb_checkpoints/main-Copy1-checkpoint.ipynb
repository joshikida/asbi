# %%
import numpy as np
from deeplenstronomy.visualize import view_image, view_image_rgb
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from scipy.stats import norm

import warnings
warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2
from active_learner import ActiveLearner
x_space = np.linspace(0.01, 0.5, 500).reshape(-1, 1)

# %%
def policy_ucb(y_pred, sigma, x_space, y_train):
    beta = 1.96
    ucb_scores = -y_pred + beta * sigma
    return x_space[np.argmax(ucb_scores)]

def policy_random(y_pred, sigma, x_space, y_train):
    random_index = np.random.choice(len(x_space))
    return x_space[random_index]
    
def policy_ei(y_pred, sigma, x_space, y_train):
    best_y_so_far = np.min(y_train)
    sigma = np.maximum(sigma, 1e-9)
    improvement = best_y_so_far - y_pred
    Z = improvement / sigma
    ei_scores = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
    return x_space[np.argmax(ei_scores)]

def policy_greedy(y_pred, sigma,x_space,y_train):
    next_design_index = np.argmin(y_pred)
    return x_space[next_design_index]

# %%
learner_ucb = ActiveLearner(x_space=x_space, acqui_policy=policy_ucb)
queried_X, queried_y = learner_ucb.run(total_queries=10, plot_progress=True)
# Out:
#  == START ACTIVE LEARNING ==
#
# Selected acquisition policy policy_ucb
# Performing 3 initial random queries
# Iteration 4/10
#   Surrogate trained on 3 points.
#   Acquisition policy selected next design: noise_std = [0.5]
#   Oracle returned performance (uncertainty): 0.0139
# Iteration 5/10
#   Surrogate trained on 4 points.
#   Acquisition policy selected next design: noise_std = [0.01]
#   Oracle returned performance (uncertainty): 0.0025
# Iteration 6/10
#   Surrogate trained on 5 points.
#   Acquisition policy selected next design: noise_std = [0.09641283]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 7/10
#   Surrogate trained on 6 points.
#   Acquisition policy selected next design: noise_std = [0.09641283]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 8/10
#   Surrogate trained on 7 points.
#   Acquisition policy selected next design: noise_std = [0.09641283]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 9/10
#   Surrogate trained on 8 points.
#   Acquisition policy selected next design: noise_std = [0.09641283]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 10/10
#   Surrogate trained on 9 points.
#   Acquisition policy selected next design: noise_std = [0.09641283]
#   Oracle returned performance (uncertainty): 0.0017

# %%
learner_ei = ActiveLearner(x_space=x_space, acqui_policy=policy_ei)
queried_X, queried_y = learner_ei.run(total_queries=10, plot_progress=True)
# Out:
#  == START ACTIVE LEARNING ==
#
# Selected acquisition policy policy_ei
# Performing 3 initial random queries
# Iteration 4/10
#   Surrogate trained on 3 points.
#   Acquisition policy selected next design: noise_std = [0.5]
#   Oracle returned performance (uncertainty): 0.0139
# Iteration 5/10
#   Surrogate trained on 4 points.
#   Acquisition policy selected next design: noise_std = [0.01]
#   Oracle returned performance (uncertainty): 0.0025
# Iteration 6/10
#   Surrogate trained on 5 points.
#   Acquisition policy selected next design: noise_std = [0.10034068]
#   Oracle returned performance (uncertainty): 0.0016
# Iteration 7/10
#   Surrogate trained on 6 points.
#   Acquisition policy selected next design: noise_std = [0.09837675]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 8/10
#   Surrogate trained on 7 points.
#   Acquisition policy selected next design: noise_std = [0.09837675]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 9/10
#   Surrogate trained on 8 points.
#   Acquisition policy selected next design: noise_std = [0.09837675]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 10/10
#   Surrogate trained on 9 points.
#   Acquisition policy selected next design: noise_std = [0.09739479]
#   Oracle returned performance (uncertainty): 0.0017

# %%
learner_random = ActiveLearner(x_space=x_space, acqui_policy=policy_random)
queried_X, queried_y = learner_random.run(total_queries=10, plot_progress=True)
# Out:
#  == START ACTIVE LEARNING ==
#
# Selected acquisition policy policy_random
# Performing 3 initial random queries
# Iteration 4/10
#   Surrogate trained on 3 points.
#   Acquisition policy selected next design: noise_std = [0.23094188]
#   Oracle returned performance (uncertainty): 0.0024
# Iteration 5/10
#   Surrogate trained on 4 points.
#   Acquisition policy selected next design: noise_std = [0.18773547]
#   Oracle returned performance (uncertainty): 0.0025
# Iteration 6/10
#   Surrogate trained on 5 points.
#   Acquisition policy selected next design: noise_std = [0.13372745]
#   Oracle returned performance (uncertainty): 0.0013
# Iteration 7/10
#   Surrogate trained on 6 points.
#   Acquisition policy selected next design: noise_std = [0.5]
#   Oracle returned performance (uncertainty): 0.0146
# Iteration 8/10
#   Surrogate trained on 7 points.
#   Acquisition policy selected next design: noise_std = [0.20933868]
#   Oracle returned performance (uncertainty): 0.0026
# Iteration 9/10
#   Surrogate trained on 8 points.
#   Acquisition policy selected next design: noise_std = [0.11310621]
#   Oracle returned performance (uncertainty): 0.0013
# Iteration 10/10
#   Surrogate trained on 9 points.
#   Acquisition policy selected next design: noise_std = [0.4646493]
#   Oracle returned performance (uncertainty): 0.0124

# %%
learner_greedy = ActiveLearner(x_space=x_space, acqui_policy=policy_greedy)
queried_X, queried_y = learner_greedy.run(total_queries=10, plot_progress=True)
# Out:
#  == START ACTIVE LEARNING ==
#
# Selected acquisition policy policy_greedy
# Performing 3 initial random queries
# Iteration 4/10
#   Surrogate trained on 3 points.
#   Acquisition policy selected next design: noise_std = [0.01]
#   Oracle returned performance (uncertainty): 0.0025
# Iteration 5/10
#   Surrogate trained on 4 points.
#   Acquisition policy selected next design: noise_std = [0.5]
#   Oracle returned performance (uncertainty): 0.0139
# Iteration 6/10
#   Surrogate trained on 5 points.
#   Acquisition policy selected next design: noise_std = [0.10230461]
#   Oracle returned performance (uncertainty): 0.0016
# Iteration 7/10
#   Surrogate trained on 6 points.
#   Acquisition policy selected next design: noise_std = [0.10034068]
#   Oracle returned performance (uncertainty): 0.0016
# Iteration 8/10
#   Surrogate trained on 7 points.
#   Acquisition policy selected next design: noise_std = [0.09935872]
#   Oracle returned performance (uncertainty): 0.0017
# Iteration 9/10
#   Surrogate trained on 8 points.
#   Acquisition policy selected next design: noise_std = [0.09935872]
#   Oracle returned performance (uncertainty): 0.0016
# Iteration 10/10
#   Surrogate trained on 9 points.
#   Acquisition policy selected next design: noise_std = [0.09935872]
#   Oracle returned performance (uncertainty): 0.0017
